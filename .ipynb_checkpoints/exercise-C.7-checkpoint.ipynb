# %%
# Exercise C7

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.model_selection import train_test_split  
from sklearn import metrics

#loads Iris dataset from url link
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

#renames columns
columnNames = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

#creates 'iris' dataframe
iris = pd.read_csv(url, names = columnNames)

#'X' groups values of sepal length/width and petal length/width columns, and 'y' groups values of species column
X = iris.iloc[:, :-1].values
y = iris.iloc[:, 4].values

#splits dataset into 80% train data and 20% test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20) 
knn = KNeighborsClassifier(n_neighbors=7)  
knn.fit(X_train, y_train)   
a_index=list(range(1,11))
a=pd.Series(dtype='float64')

#calculates accuracy of model for different values of k
for i in np.arange(1, 10):
    knn2 = KNeighborsClassifier(n_neighbors=i)
    knn2.fit(X_train, y_train)
    print("For k = %d accuracy is"%i,knn2.score(X_test,y_test))
    
#plots performance for different values of k
print("Different Values of 'n' for K-Nearest Neighbors:")    
for i in list(range(1,11)):
    model=KNeighborsClassifier(n_neighbors=i) 
    model.fit(X_train,y_train)
    prediction=model.predict(X_test)
    a=a.append(pd.Series(metrics.accuracy_score(prediction,y_test)))
plt.plot(a_index, a)
plt.show()
# Out:
# For k = 1 accuracy is 1.0
# For k = 2 accuracy is 0.8333333333333334
# For k = 3 accuracy is 0.9333333333333333
# For k = 4 accuracy is 0.8666666666666667
# For k = 5 accuracy is 0.9333333333333333
# For k = 6 accuracy is 0.9
# For k = 7 accuracy is 0.9333333333333333
# For k = 8 accuracy is 0.9
# For k = 9 accuracy is 0.9333333333333333
# Different Values of 'n' for K-Nearest Neighbors:
