# %%
# Exercise B1

import pandas as pd
import matplotlib.pyplot as plt

#loads Iris dataset from url link
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

#renames columns
columnNames = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

#creates 'iris' dataframe
iris = pd.read_csv(url, names = columnNames)

#plots general Statistics of Iris data
iris.describe().plot()
plt.xlabel('Statistic')
plt.ylabel('Value')
plt.title('General Statistics of Iris Data')
plt.show()
